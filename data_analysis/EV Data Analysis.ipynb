# %% [markdown]
# # import pandas
#
# pandas.options.display.max_columns = None
# pandas.options.display.max_rows = None

# %%
import pandas

import matplotlib.pyplot as plt

import seaborn as sns

# %%
ev_data = pandas.read_csv ("ElectricCarData_Clean.csv") 

ev_data
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
#we want to outline the questions we will be adressing though the data analysis.

# %% [markdown]
# # EV data features set Key
#
# B= Brand
#
# M = Model
#
# A= Accel
#
# TS= Top Speed
#
# R= Range
#
# E = Efficiency
#
# FC= Fast Charge
#
# RC= Rapid Charge
#
# PTR= PowerTrain
#
# PTY= Plug Type
#
# BS= Body Style
#
# S= Segment
#
# STS= Seats
#
# PE= Price Euro

# %%
ev_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    object
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    object
#  7   RapidCharge      103 non-null    object
#  8   PowerTrain       103 non-null    object
#  9   PlugType         103 non-null    object
#  10  BodyStyle        103 non-null    object
#  11  Segment          103 non-null    object
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 11.4+ KB

# %% [markdown]
# ##Question 1: Which Brand has the fastest top speed?

# %%
d3=ev_data.loc[:, ['Brand','TopSpeed_KmH']]
d3.head()
# selecting the data
# Out:
#          Brand  TopSpeed_KmH
# 0       Tesla            233
# 1  Volkswagen            160
# 2    Polestar            210
# 3         BMW            180
# 4       Honda            145

# %% [markdown]
# ##Question 2:Does faster acceleration mean faster Top Speed?

# %%
ev_data.plot(x="Brand", y=["AccelSec",])
plt.show()

# %%
ev_data.plot(x="Brand", y=["TopSpeed_KmH",])
plt.show()

# %% [markdown]
# ##Question 3: Which brand has the highest efficiency?

# %%
ev_data.plot(kind='scatter', x = 'Brand', y='efficency', figsize=(27,10))
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='PriceEuro'>

# %% [markdown]
# Question 4:How does price relate to how many seats in a car?

# %%
ev_data.plot(x="Brand", y=["PriceEuro",])
plt.show()

# %%
ev_data.plot(x="Brand", y=["Seats",])
plt.show()

# %% [markdown]
# Question 5: Which Body style has the most and least efficiency?

# %%
ev_data.plot(x="Brand", y=["Efficiency_WhKm",])
plt.show()

# %% [markdown]
# Question 6: Which Brand has the most expensive car and the cheapest car?

# %%
ev_data.plot(kind='scatter', x = 'Brand', y='PriceEuro', figsize=(27,10))
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='PriceEuro'>

# %% [markdown]
# Question 7:Does car segment affect efficiency?

# %%
ev_data.plot(x="Segment", y=["Efficiency_WhKm",])
plt.show()

# %% [markdown]
# Question 8: Does a difference in power train affect top speed?

# %%
ev_data.plot(x="PowerTrain", y=["TopSpeed_KmH",])
plt.show()

# %% [markdown]
#  Question 9: Does high or low  top speed affect the car's efficiency?

# %%
ev_data.plot(kind='scatter', x = 'TopSpeed_KmH', y='Efficiency_WhKm', figsize=(27,10))
# Out:
# <AxesSubplot:xlabel='TopSpeed_KmH', ylabel='Efficiency_WhKm'>

# %% [markdown]
# Question 10: WHich car brand makes the most amount of EVs

# %%
Most_car=ev_data.groupby('Brand').count()
print(Most_car['Model'].sort_values(ascending = False))
# Out:
# Brand
# Tesla          13
# Audi            9
# Nissan          8
# Volkswagen      8
# Skoda           6
# Kia             5
# Porsche         5
# Renault         5
# BMW             4
# Ford            4
# Smart           3
# Mercedes        3
# Opel            3
# Hyundai         3
# Byton           3
# Peugeot         2
# Honda           2
# Fiat            2
# SEAT            1
# Sono            1
# Polestar        1
# Aiways          1
# MG              1
# Mini            1
# Mazda           1
# Lucid           1
# Lightyear       1
# Lexus           1
# Jaguar          1
# DS              1
# Citroen         1
# CUPRA           1
# Volvo           1
# Name: Model, dtype: int64
